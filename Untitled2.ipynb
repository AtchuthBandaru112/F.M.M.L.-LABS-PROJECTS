# %% [markdown]
# <a href="https://colab.research.google.com/github/AtchuthBandaru112/F.M.M.L.-LABS-PROJECTS/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
for i in range (1, 11):
   print(f"{n}*{i}={5*i}")
# Out:
# 5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
